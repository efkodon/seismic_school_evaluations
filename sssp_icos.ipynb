# %%
import pandas as pd
import seaborn as sns
import numpy as np
from numpy import nan

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('max_seq_item', None)

# %%
# DATA SOURCE 1: DATASET FROM INFORMATION AND CONDITION OF SCHOOLS (ICOS), Pre-Disaster Mitigation module.
# Received from WA Office of Superintendent of Public Instruction (OSPI), 8/14/24, via public records request.
# https://www.k12.wa.us/policy-funding/school-buildings-facilities/information-and-condition-schools-icos
df_icos_original=pd.read_csv("data/df_icos_clean_8.14.24.csv")

# %%
# Copy the data and work with the copy.
df_icos = df_icos_original

# %%
df_icos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6678 entries, 0 to 6677
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unique_Identifier                    6678 non-null   object
#  1   District                             6678 non-null   object
#  2   Site                                 6678 non-null   object
#  3   Site_Latitude                        6678 non-null   float64
#  4   Site_Longitude                       6678 non-null   float64
#  5   Site_Type                            6678 non-null   object
#  6   Site_EQHazardLevel                   6678 non-null   object
#  7   Site_EQRiskLevel                     6678 non-null   object
#  8   Site_Soil                            6638 non-null   object
#  9   Site_Liquefaction                    6638 non-null   object
#  10  Site_GroundMotionPercentile          6638 non-null   float64
#  11  Site_HasGeotechnicalStudy            6678 non-null   object
#  12  Site_ShearWaveVelocity               1196 non-null   float64
#  13  Site_EnrollmentSchoolYear            6678 non-null   object
#  14  Site_Enrollment                      6678 non-null   object
#  15  BuildingID                           6655 non-null   float64
#  16  Building                             6655 non-null   object
#  17  Building_Type                        6655 non-null   object
#  18  Building_HasEvaluation               6678 non-null   object
#  19  Building_YearBuilt                   6655 non-null   float64
#  20  Building_GrossSqFt                   6619 non-null   object
#  21  BuildingArea_Name                    6627 non-null   object
#  22  BuildingArea_YearBuilt               6627 non-null   float64
#  23  BuildingArea_CodeYear                6627 non-null   object
#  24  BuildingArea_NumberOfFloors          5421 non-null   float64
#  25  BuildingArea_ConstructionType        6678 non-null   object
#  26  BuildingArea_VerticalIrregularity    1027 non-null   object
#  27  BuildingArea_HorizontalIrregularity  1558 non-null   object
#  28  BuildingArea_ExistingRisk            6678 non-null   object
#  29  BuildingArea_HasRetrofit             6655 non-null   object
#  30  BuildingArea_RetrofitRisk            6678 non-null   object
#  31  BuildingArea_CodeRisk                2441 non-null   object
# dtypes: float64(8), object(24)
# memory usage: 1.6+ MB

# %%
# converts values to a numeric data type
df_icos['BuildingID'] = df_icos['BuildingID'].astype('Int64')
df_icos['Building_YearBuilt'] = df_icos['Building_YearBuilt'].astype('Int64')

# %%
# How many seismic evaluations conducted in the School Seismic Safety Project are not shown in ICOS?

# %%
# Gets rid of extra spaces that could prevent merging
df_icos['Site'] = df_icos['Site'].str.strip()
df_icos['Building'] = df_icos['Building'].str.strip()

# %%
# DATA SOURCE 2: SCHOOL SEISMIC SAFETY PROJECT (SSSP), Washington State Department of Natural Resources.
# SSSP Phase 2 Report, 2019-2021 Legislative Report (6/30/21), table on pages 94-141. Data scraped from:
# https://fortress.wa.gov/dnr/geologydata/school_seismic_safety/phase2/School_Seismic_Safety_Project_2021_Final_Report_DNR.pdf
df_sssp_original=pd.read_csv("data/sssp_2021_legislative_report.csv")

# %%
# Copy the data and work with the copy
df_sssp = df_sssp_original

# %%
# Rename columns to match ICOS columns for merging. The "ICOS#" column in SSSP refers to the BuildingID column 
# in ICOS (source: OSPI). 
df_sssp.rename(columns={'District Name': 'District', 'Facility Name': 'Site','Building Name': 'Building', \
                                     'ICOS#': 'BuildingID'}, inplace=True)

# %%
# converts values to a numeric data type
df_sssp['BuildingID'] = df_sssp['BuildingID'].astype('Int64')

# %%
# These additional columns will be needed later to make edits for matching with ICOS values.
# The "original" columns will retain original values, and edits will be made to the columns on the right.
df_sssp['original_BuildingID_SSSP'] = df_sssp['BuildingID']
df_sssp['original_Building_SSSP'] = df_sssp['Building']

# %%
# According to the SSSP, the project assessed 561 school buildings (274 schools at 245 campuses).
# There are 516 Building IDs in the SSSP data. 
sssp_buildings = df_sssp['BuildingID'].nunique()
print("There are", sssp_buildings, "Building IDs in the SSSP data.")
# Out:
# There are 516 Building IDs in the SSSP data.

# %%
# Analysis further below will show that some records with matching Building IDs in both data sources do
# not match by school or building name. So matching by Building ID alone could lead to errors.
# School and building names are also needed for matching records between the two data sources.

# %%
# DATA CLEANING
# Three Building IDs from the SSSP are missing in ICOS, because ICOS has different IDs for two buildings, 
# and one school closed. In addition, one school name is misspelled in the SSSP data. 
# Below, these SSSP data discrepancies are fixed to match the data in ICOS.

# %%
# removes extra spaces that can prevent merging
df_sssp['Site'] = df_sssp['Site'].str.strip()

# %%
# Create a one-column list of the 516 unique Building IDs in the SSSP to search ICOS for BuildingID matches.
df_sssp2 = df_sssp['BuildingID']
df_sssp2 = df_sssp2.drop_duplicates()

# Columns became a list of BuildingIDs; reset the index to restore the dataframe to two columns.
df_sssp2 = df_sssp2.reset_index() 

# Capture only the BuildingID column. This variable can be used to search ICOS.
df_sssp_ids = df_sssp2['BuildingID']

# %%
# Find all rows in ICOS with Building IDs that are also found in the SSSP. 
df_icos2 = df_icos[df_icos['BuildingID'].isin(df_sssp_ids)]
df_icos2.shape
# Out:
# (865, 32)

# %%
# There are 516 unique building IDs in the SSSP, but only 513 of these are found in ICOS. 
df_icos_ids = df_icos2['BuildingID'].drop_duplicates()
df_icos_ids.shape
# Out:
# (513,)

# %%
# Identify the three building IDs from the SSSP that do not appear in ICOS.
df_bldgs_missing = df_sssp_ids[~df_sssp_ids.isin(df_icos_ids)]
df_bldgs_missing
# Out:
# 43     50960
# 414    53918
# 416    53919
# Name: BuildingID, dtype: Int64

# %%
# These are the three buildings with Building IDs from the SSSP that are not in ICOS. 
df_bldgs_missing2 = df_sssp[df_sssp['BuildingID'].isin(df_bldgs_missing)]
df_bldgs_missing2
# Out:
#     Priority level      District                         Site  \
# 43       Very High  Mount Vernon    Lincoln Elementary School
# 446       Moderate        Yakima  Robertson Elementary School
# 448       Moderate        Yakima  Robertson Elementary School
#
#                     Building  BuildingID  original_BuildingID_SSSP  \
# 43             Main Building       50960                     50960
# 446  100 Building - Bldg "B"       53918                     53918
# 448  300 Building - Bldg "D"       53919                     53919
#
#       original_Building_SSSP
# 43             Main Building
# 446  100 Building - Bldg "B"
# 448  300 Building - Bldg "D"

# %%
# Lincoln Elementary School in Mount Vernon is not in ICOS, and online sources say it closed in 2021,
# although the building was still being used by students from another school as recently as 2021. 
# https://www.publicschoolreview.com/lincoln-elementary-school-profile/98274
df_icos_bldg_search = df_icos[['District', 'Site', 'BuildingID','Building', 'BuildingArea_Name']]

mask = (df_icos_bldg_search['Site'] == 'Lincoln Elementary School') & \
(df_icos_bldg_search['District'] == 'Mount Vernon')

df_bldgs_missing3 = df_icos_bldg_search[mask]
df_bldgs_missing3.shape
# Out:
# (0, 5)

# %%
# The other two buildings are in ICOS with different Building IDs than in the SSSP.
mask = (df_icos_bldg_search['Site'] == 'Robertson Elementary School') & \
(df_icos_bldg_search['District'] == 'Yakima') & \
(df_icos_bldg_search['Building'].str.contains('100 Building'))

mask2 = (df_icos_bldg_search['Site'] == 'Robertson Elementary School') & \
(df_icos_bldg_search['District'] == 'Yakima') & \
(df_icos_bldg_search['Building'].str.contains('300 Building'))

df_bldgs_missing4 = df_icos_bldg_search[mask]
df_bldgs_missing5 = df_icos_bldg_search[mask2]
df_bldgs_missing6 = (df_bldgs_missing4, df_bldgs_missing5)
df_bldgs_missing7 = pd.concat(df_bldgs_missing6)
df_bldgs_missing7
# Out:
#      District                         Site  BuildingID          Building  \
# 6614   Yakima  Robertson Elementary School       53928  100 Building - B
# 6616   Yakima  Robertson Elementary School       53922  300 Building - D
#
#      BuildingArea_Name
# 6614         Main Area
# 6616         Main Area

# %%
# This school is misspelled in the SSSP. The correct spelling is "Prairie": https://phs.battlegroundps.org/
mask = (df_sssp['Site'] == 'Praire High School') 
df_sssp_bldgs_typo = df_sssp[mask]
df_sssp_bldgs_typo
# Out:
#     Priority level       District                Site      Building  \
# 87            High  Battle Ground  Praire High School  500 Building
# 88            High  Battle Ground  Praire High School  600 Building
# 459          Lower  Battle Ground  Praire High School  400 Building
#
#      BuildingID  original_BuildingID_SSSP original_Building_SSSP
# 87        50021                     50021           500 Building
# 88        50024                     50024           600 Building
# 459       50013                     50013           400 Building

# %%
# This is the correct spelling of the school name.
df_icos_bldg_search2 = df_icos_bldg_search[['District', 'Site']]

mask = (df_icos_bldg_search2['Site'] == 'Prairie High School') 

df_sssp_bldgs_typo3 = df_icos_bldg_search2[mask]
df_sssp_bldgs_typo4 = df_sssp_bldgs_typo3.drop_duplicates()
df_sssp_bldgs_typo4
# Out:
#           District                 Site
# 225  Battle Ground  Prairie High School

# %%
# Copy the SSSP data and adjust the two Building IDs that did not match ICOS so that they will match, 
# and fix the school name typo in the SSSP so the school name will match ICOS.
df_sssp3 = df_sssp

# %%
df_sssp3.at[446, 'BuildingID'] = 53928
df_sssp3.at[448, 'BuildingID'] = 53922
df_sssp3.at[87, 'Site'] = 'Prairie High School'
df_sssp3.at[88, 'Site'] = 'Prairie High School'
df_sssp3.at[459, 'Site'] = 'Prairie High School'

# %%
# Verify that the typo in this school name has been fixed in the SSSP data.
df_sssp3.iloc[[87, 88, 459]]
# Out:
#     Priority level       District                 Site      Building  \
# 87            High  Battle Ground  Prairie High School  500 Building
# 88            High  Battle Ground  Prairie High School  600 Building
# 459          Lower  Battle Ground  Prairie High School  400 Building
#
#      BuildingID  original_BuildingID_SSSP original_Building_SSSP
# 87        50021                     50021           500 Building
# 88        50024                     50024           600 Building
# 459       50013                     50013           400 Building

# %%
df_sssp3.iloc[[446, 448]]
# Out:
#     Priority level District                         Site  \
# 446       Moderate   Yakima  Robertson Elementary School
# 448       Moderate   Yakima  Robertson Elementary School
#
#                     Building  BuildingID  original_BuildingID_SSSP  \
# 446  100 Building - Bldg "B"       53928                     53918
# 448  300 Building - Bldg "D"       53922                     53919
#
#       original_Building_SSSP
# 446  100 Building - Bldg "B"
# 448  300 Building - Bldg "D"

# %%
df_sssp3.shape
# Out:
# (556, 7)

# %%
# Repeat several steps from above with the adjusted data to create a new list of SSSP building IDs to search ICOS.

# %%
df_sssp4 = df_sssp3['BuildingID']
df_sssp5 = df_sssp4.drop_duplicates()
df_sssp5.shape
# Out:
# (516,)

# %%
df_sssp5 = df_sssp5.reset_index()

# %%
# This single column list can now be used to search through the ICOS Building ID column.
df_sssp5 = df_sssp5['BuildingID']

# %%
df_icos_2 = df_icos[df_icos['BuildingID'].isin(df_sssp5)]
df_icos_2.shape
# Out:
# (867, 32)

# %%
# Identify the buildings in the SSSP that are marked as retrofitted in ICOS.
df_icos_2['BuildingArea_HasRetrofit'].value_counts()
# Out:
# BuildingArea_HasRetrofit
# No            852
# Structural     15
# Name: count, dtype: int64

# %%
mask = (df_icos_2['BuildingArea_HasRetrofit'] == 'Structural')
df_icos_2_retrofit = df_icos_2[mask]
df_icos_2_retrofit[['District', 'Site', 'Building', 'BuildingArea_HasRetrofit']]\
   .drop_duplicates() # These buildings are marked as retrofited in the SSSP list, but there is no retrofit
# date to know if those retrofits happened before or after the project ended.
# Out:
#         District                                                     Site  \
# 10      Aberdeen                              McDermoth Elementary School
# 43     Anacortes                             Mount Erie Elementary School
# 643    Carbonado                           Carbonado Historical School 19
# 1531     Everett                                Jackson Elementary School
# 3954  Oak Harbor                           Oak Harbor Intermediate School
# 3955  Oak Harbor                           Oak Harbor Intermediate School
# 3957  Oak Harbor                           Oak Harbor Intermediate School
# 3959  Oak Harbor                           Oak Harbor Intermediate School
# 6293   Wahkiakum  Julius A. Wendt Elementary/John C. Thomas Middle School
#
#                          Building BuildingArea_HasRetrofit
# 10                  Main Building               Structural
# 43                  Main Building               Structural
# 643             A - Main Building               Structural
# 1531                Main Building               Structural
# 3954                   Building B               Structural
# 3955                       C Wing               Structural
# 3957                       D Wing               Structural
# 3959              Main Building A               Structural
# 6293  J A Wendt Elementary School               Structural

# %%
# There are 867 rows in ICOS that match 515 Building IDs in the SSSP. 
# The adjustments above correctly raised the totals by 2 each.
df_icos_2['BuildingID'].nunique()
# Out:
# 515

# %%
# DATA CLEANING: Identify school names that do not match between the SSSP and ICOS. See if small adjustments can be 
# made to school names in the SSSP to match ICOS for merging when they clearly refer to the same school.

# %%
# Create a unique ID combining school and district because some school names are used by multiple districts.
df_sssp3['Unique_Identifier'] = df_sssp3['District'].astype(str) +"_"+ df_sssp3['Site'].astype(str)

# %%
df_sssp3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 556 entries, 0 to 555
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Priority level            556 non-null    object
#  1   District                  556 non-null    object
#  2   Site                      556 non-null    object
#  3   Building                  556 non-null    object
#  4   BuildingID                556 non-null    Int64
#  5   original_BuildingID_SSSP  556 non-null    Int64
#  6   original_Building_SSSP    556 non-null    object
#  7   Unique_Identifier         556 non-null    object
# dtypes: Int64(2), object(6)
# memory usage: 36.0+ KB

# %%
df_sssp_sites = df_sssp3[['Unique_Identifier', 'District', 'Site']].drop_duplicates()
df_sssp_sites.shape
# The SSSP reports say there were 274 schools at 245 campuses in the study. This shows 277. This could be due
# to name variations making this appear to be several more schools than the actual number.
# Out:
# (277, 3)

# %%
df_icos_sites = df_icos_2[['Unique_Identifier', 'District', 'Site']].drop_duplicates()
df_icos_sites.shape
# Out:
# (271, 3)

# %%
df_sssp_ids = df_sssp_sites['Unique_Identifier'].drop_duplicates()
df_sssp_ids.shape
# Out:
# (277,)

# %%
df_icos_ids = df_icos_sites['Unique_Identifier'].drop_duplicates()
df_icos_ids.shape
# There are 271 schools in ICOS that have matched the SSSP school names so far.
# Out:
# (271,)

# %%
df_test1 = df_icos_sites[~df_icos_sites['Unique_Identifier'].isin(df_sssp_ids)]
df_test1.shape
# Out:
# (15, 3)

# %%
df_test1['Unique_Identifier'].unique() # These are the schools in ICOS not found in the SSSP, despite
# having common Building IDs
# Out:
# array(['Bellingham_Happy Valley Elementary School ',
#        'Burlington-Edison_West View Elementary School',
#        'Cape Flattery_Clallam Bay K-12 School',
#        'Cape Flattery_Neah Bay Secondary School',
#        'Central Kitsap_Ridgetop Middle School',
#        'La Conner_La Conner Middle School (form. Elem site.)',
#        'Mount Baker_Mount Baker Junior High School',
#        'Oak Harbor_Clover Valley Home Connection',
#        'Oak Harbor_Oak Harbor Intermediate School',
#        'Quillayute Valley_Forks Middle School',
#        'South Whidbey_South Whidbey South Campus - (Formerly S. Whid. Primary)',
#        'Spokane_Bryant',
#        'Wahkiakum_Julius A. Wendt Elementary/John C. Thomas Middle School',
#        'Warden_Middle / High School',
#        'Woodland_Woodland Middle School (old HS)'], dtype=object)

# %%
df_test2 = df_sssp_sites[~df_sssp_sites['Unique_Identifier'].isin(df_icos_ids)]
df_test2.shape
# Out:
# (21, 3)

# %%
df_test2['Unique_Identifier'].unique() # These are the schools in the SSSP not found in the ICOS list that was
# pulled in via common Building IDs. Adjust names with minor variations to match the ICOS list above.
# Any schools listed here and not in the ICOS list above may have been missed due to Building ID differences.
# Out:
# array(['Burlington-Edison_West View Elementary School School',
#        'Cape Flattery_Clallam Bay High and Elementary School',
#        'Cape Flattery_Neah Bay Junior/ Senior High  School',
#        'La Conner_La Conner Middle School (form. Elem.)',
#        'Marysville_Marysville Pilchuck Sr High School',
#        'Mount Vernon_Lincoln Elementary School',
#        'Quillayute Valley_Forks Intermediate School',
#        'Quillayute Valley_Forks Jr-Sr High School',
#        'Woodland_Woodland Middle School',
#        'Cape Flattery_Neah Bay Jr/ Sr High School',
#        'Oak Harbor_Clover Valley School',
#        'Oak Harbor_Oak Harbor Middle School',
#        'South Whidbey_South Whidbey Grades 5 & 6',
#        'Spokane_Bryant Center',
#        'Wahkiakum_Julius A. Wendt ES/John C. Thomas MS',
#        'Cape Flattery_Neah Bay Junior/ Senior High School',
#        'Central Kitsap_Ridgetop Junior High',
#        'Mount Baker_Mount Baker Jr High School',
#        'Mount Baker_Mount Baker Sr High School',
#        'Thorp_Thorp Elementary and Jr-Sr High School',
#        'Warden_Warden K-12'], dtype=object)

# %%
df_sssp3['Site'] = df_sssp3['Site'].replace(["West View Elementary School School"], "West View Elementary School)")
df_sssp3['Site'] = df_sssp3['Site'].replace(["La Conner Middle School (form. Elem.)"], \
                                            "La Conner_La Conner Middle School (form. Elem site.)")
df_sssp3['Site'] = df_sssp3['Site'].replace(["Mount Baker_Mount Baker Jr High School"], \
                                            "Mount Baker Junior High School)")
df_sssp3['Site'] = df_sssp3['Site'].replace(["Clover Valley School"], \
                                            "Clover Valley Home Connection")
df_sssp3['Site'] = df_sssp3['Site'].replace(["Oak Harbor Middle School"], \
                                            "Oak Harbor Intermediate School")
df_sssp3['Site'] = df_sssp3['Site'].replace(["Forks Jr-Sr High School"], \
                                            "Forks Junior-Senior High School")
df_sssp3['Site'] = df_sssp3['Site'].replace(["South Whidbey_South Whidbey Grades 5 & 6"], \
                                            "South Whidbey South Campus - (Formerly S. Whid. Primary)'")
df_sssp3['Site'] = df_sssp3['Site'].replace(["Bryant Center"], "Bryant")
df_sssp3['Site'] = df_sssp3['Site'].replace(["Julius A. Wendt ES/John C. Thomas MS"], \
                                            "Julius A. Wendt Elementary/John C. Thomas Middle School")
df_sssp3['Site'] = df_sssp3['Site'].replace(["Ridgetop Junior High"], \
                                            "Ridgetop Middle School")
df_sssp3['Site'] = df_sssp3['Site'].replace(["Warden_Warden K-12"], \
                                            "Warden_Middle / High School")
df_sssp3['Site'] = df_sssp3['Site'].replace(["Woodland Middle School"], \
                                            "Woodland Middle School (old HS)")

# %%
# Test to see which ones still do not match now.

# %%
df_sssp_sites2 = df_sssp3[['District', 'Site']].drop_duplicates()
df_sssp_sites2.shape
# Out:
# (277, 2)

# %%
# Make unique identifiers again with the adjusted names
df_sssp_sites2['Unique_Identifier'] = df_sssp_sites2['District'].astype(str) +"_"+ \
     df_sssp_sites2['Site'].astype(str)

# %%
df_sssp_sites3 = df_sssp_sites2[['Unique_Identifier', 'District', 'Site']].drop_duplicates()
df_sssp_sites3.shape
# Out:
# (277, 3)

# %%
df_sssp_ids2 = df_sssp_sites2['Unique_Identifier'].drop_duplicates()
df_sssp_ids2.shape
# Out:
# (277,)

# %%
df_test3 = df_icos_sites[~df_icos_sites['Unique_Identifier'].isin(df_sssp_ids2)]
df_test3.shape
# There are still 9 schools that were not pulled in via Building IDs.
# Out:
# (9, 3)

# %%
# MERGING

# %%
# Make copies for merging.
df_icos_to_combine = df_icos_2
df_sssp_to_combine = df_sssp3

# %%
df_sssp_bldgs1 = df_sssp3[['District', 'Site', 'Building']].drop_duplicates()
df_sssp_bldgs1.shape
# Out:
# (556, 3)

# %%
# There are 516 unique building IDs for the 556 building areas in the SSSP data. These match to 515 IDs
# in ICOS, since one school closed and is not in ICOS. The ICOS rows for these buildings total 867.

# %%
# MERGE
# df_icos_to_combine      (867 rows, 515 Building IDs, 32 columns)
# df_sssp_to_combine      (556 rows, 516 Building IDs, 6 columns)

# %%
# Adjust building names for matching where slight, non-substantive differences are present. 
# Some building IDs are used with multiple building area rows.

# %%
df_bldg_names_icos = df_icos_to_combine[['Site','BuildingID', 'Building', 'BuildingArea_Name']]
# This contains 515 building IDs, each used once.

# %%
df_bldg_names_icos.shape
# Out:
# (867, 4)

# %%
df_bldg_names_icos2 = df_bldg_names_icos.drop_duplicates()
df_bldg_names_icos2.shape
# This lists has one row per Building ID, 515 without building area name added above.
# Out:
# (807, 4)

# %%
df_bldg_names_icos2['BuildingID'].nunique()
# Out:
# 515

# %%
df_bldg_names_icos2['Site'].nunique() # there are 262 schools in the ICOS list of 515 buildings
# Out:
# 262

# %%
df_bldg_names_sssp = df_sssp_to_combine[['Site','BuildingID', 'Building']]

# %%
df_bldg_names_sssp.shape
# Out:
# (556, 3)

# %%
merged_sssp_icos_bldgs = df_bldg_names_sssp.merge(df_bldg_names_icos2, how = 'left', on = ['BuildingID'])

# %%
merged_sssp_icos_bldgs.shape
# Out:
# (894, 6)

# %%
df_icos_to_combine_2 = df_icos_to_combine.groupby(['District', 'Site', 'BuildingID', 'Building', \
                'Building_HasEvaluation', 'Building_YearBuilt'], \
                as_index=False).agg({'BuildingArea_ExistingRisk': ' '.join})

# %%
merged_sssp_icos_df = df_sssp_to_combine.merge(df_icos_to_combine_2, how = 'inner', on = ['BuildingID', \
                                                                                          'District'])

# %%
merged_sssp_icos_df.shape
# There are 555 building names in the SSSP, matched to 515 building IDs in ICOS, some of which are repeated.
# Out:
# (555, 13)

# %%
merged_sssp_icos_df['building match'] = merged_sssp_icos_df.apply(lambda x: 'Yes' if\
                                                             x['Building_x'] in x['Building_y'] else 'No',axis=1)

# %%
merged_sssp_icos_df['site match'] = merged_sssp_icos_df.apply(lambda x: 'Yes' if\
                                                             x['Site_x'] in x['Site_y'] else 'No',axis=1)

# %%
merged_sssp_icos_df.rename(columns={'Site_x': 'Site_SSSP', 'Site_y': 'Site_ICOS', 'Building_x': 'Building_SSSP', \
                                     'Building_y': 'Building_ICOS'}, inplace=True)

# %%
# Check the school names that did not match and see if the differences are minor or substantial.
merged_sssp_icos_df2 = merged_sssp_icos_df[['Site_SSSP', 'Site_ICOS', 'site match']]
mask = (merged_sssp_icos_df2['site match'] == 'No')
merged_sssp_icos_df3 = merged_sssp_icos_df2[mask]
merged_sssp_icos_df3 = merged_sssp_icos_df3.drop_duplicates()
merged_sssp_icos_df3
# By observation, these are all correctly matched with minor variations. One exception is "Warden K-12" in the 
# SSSP, which is listed as "Middle / High School" in ICOS, but the Warden district has only two schools in ICOS,  
# and the other one is an elementary school, so this appears correctly matched too. https://www.warden.wednet.edu/
# Use the SSSP site list in subsequent dataframes and ignore the ICOS site list.
# Out:
#                                                 Site_SSSP  \
# 11                           West View Elementary School)
# 12                 Clallam Bay High and Elementary School
# 14                   Neah Bay Junior/ Senior High  School
# 33   La Conner_La Conner Middle School (form. Elem site.)
# 37                     Marysville Pilchuck Sr High School
# 55                              Forks Intermediate School
# 56                        Forks Junior-Senior High School
# 110                           Neah Bay Jr/ Sr High School
# 310                            South Whidbey Grades 5 & 6
# 463                               Fairhaven Middle School
# 468                   Neah Bay Junior/ Senior High School
# 509                            Mount Baker Jr High School
# 511                            Mount Baker Sr High School
# 542                Thorp Elementary and Jr-Sr High School
# 548                                           Warden K-12
#
#                                                     Site_ICOS site match
# 11                                West View Elementary School         No
# 12                                    Clallam Bay K-12 School         No
# 14                                  Neah Bay Secondary School         No
# 33                 La Conner Middle School (form. Elem site.)         No
# 37                     Marysville Pilchuck Senior High School         No
# 55                                        Forks Middle School         No
# 56                                        Forks Middle School         No
# 110                                 Neah Bay Secondary School         No
# 310  South Whidbey South Campus - (Formerly S. Whid. Primary)         No
# 463                            Happy Valley Elementary School         No
# 468                                 Neah Bay Secondary School         No
# 509                            Mount Baker Junior High School         No
# 511                            Mount Baker Senior High School         No
# 542            Thorp Elementary and Junior Senior High School         No
# 548                                      Middle / High School         No

# %%
# Create a list of building names that do not match between the SSSP and ICOS. There are 115 mis-matched names.
merged_sssp_icos_df_buildings = merged_sssp_icos_df[['BuildingID', 'original_Building_SSSP', 'Building_SSSP', \
                  'Building_ICOS', 'building match', 'Building_HasEvaluation', 'BuildingArea_ExistingRisk']]
mask = (merged_sssp_icos_df_buildings['building match'] == 'No')
merged_sssp_icos_df_buildings2 = merged_sssp_icos_df_buildings[mask]
merged_sssp_icos_df_buildings2 = merged_sssp_icos_df_buildings2.drop_duplicates()
# drop buildings match column
merged_sssp_icos_df_buildings2.shape
# Out:
# (123, 7)

# %%
# Check the building names that did not match and see if the differences are minor or substantial.
# For small, non-substantive variations, make adjustments to SSSP building names to match ICOS.
# merged_sssp_icos_df_buildings2[['Building_SSSP', 'Building_ICOS']]

# %%
# Adjust minor variations in the SSSP building names to match ICOS. Keep the original names too.
# First, do this just to the list of buildings with mismatched names. Verify that it looks right.
# Then apply the changes to the whole merged dataframe of all buildings, including those previously matched.
# After correcting the building names, re-merge.
buildings = [4, 10, 55, 56, 58, 61, 62, 65, 69, 70, 71, 74, 75, 76, 157, 158, 185, 187, 209, 212, 216, 217, 220, \
            246, ]
for i in buildings:
    merged_sssp_icos_df['Building_SSSP'].iloc[i] = merged_sssp_icos_df\
    ['Building_ICOS'].iloc[i]

# %%
# Apply the changes to the whole merged dataframe
buildings = [1, 2, 4, 5]
for i in buildings:
    merged_sssp_icos_df['Building_SSSP'].iloc[i] = merged_sssp_icos_df\
    ['Building_ICOS'].iloc[i]

# %%
# Make a copy to work with
df_sssp_to_combine = df_sssp3

# %%
# Repeat merge with corrected data. 
merged_sssp_icos_df2 = df_sssp_to_combine.merge(df_icos_to_combine_2, how = 'inner', on = ['BuildingID', \
                                                                                          'District'])

# %%
merged_sssp_icos_df2['buildings match'] = merged_sssp_icos_df2.apply(lambda x: 'Yes' if\
                                                             x['Building_x'] in x['Building_y'] else 'No',axis=1)

# %%
merged_sssp_icos_df2['Building_HasEvaluation'].value_counts()
# Out:
# Building_HasEvaluation
# Yes    347
# No     208
# Name: count, dtype: int64

# %%
merged_sssp_icos_df2.rename(columns={'Site_x': 'Site_SSSP', 'Site_y': 'Site_ICOS', 'Building_x': 'Building_SSSP', \
                                     'Building_y': 'Building_ICOS'}, inplace=True)

# %%
# Re-run the above code to check how many building names are still mis-matched, with substantial differences.
merged_sssp_icos_df2_buildings = merged_sssp_icos_df2[['Building_SSSP', 'Building_ICOS', 'buildings match', \
                                                      'Building_HasEvaluation']]
mask = (merged_sssp_icos_df2_buildings['buildings match'] == 'No')
merged_sssp_icos_df2_buildings2 = merged_sssp_icos_df2_buildings[mask]
merged_sssp_icos_df2_buildings3 = merged_sssp_icos_df2_buildings2.drop_duplicates()
# merged_sssp_icos_df2_buildings3

# %%
# Have any buildings been replaced since the SSSP data was collected?
# The SSSP started in 2017. Does the data show any buildings that were replaced since then, which
# could explain missing evaluations? 
mask = (merged_sssp_icos_df2['Building_YearBuilt'] > 2016)

merged_sssp_icos_df3 = merged_sssp_icos_df2[mask]
merged_sssp_icos_df3.shape
# Answer: no, there are none.
# Out:
# (0, 14)

# %%
# EVALUATIONS

# %%
merged_sssp_icos_df2['BuildingID'].nunique()
# Out:
# 515

# %%
merged_sssp_icos_df2['Building_HasEvaluation'].value_counts()
# Out:
# Building_HasEvaluation
# Yes    347
# No     208
# Name: count, dtype: int64

# %%
mask = (merged_sssp_icos_df2['Building_HasEvaluation'] == 'Yes')
merged_sssp_icos_eval = merged_sssp_icos_df2[mask]
merged_sssp_icos_eval.shape
# Out:
# (347, 14)

# %%
merged_sssp_icos_eval['BuildingID'].nunique() # there are 316 out of 516 buildings with one or more evaluation
# Out:
# 330

# %%
mask = (merged_sssp_icos_df2['Building_HasEvaluation'] == 'No')
merged_sssp_icos_no_eval = merged_sssp_icos_df2[mask]
merged_sssp_icos_no_eval.shape
# Out:
# (208, 14)

# %%
merged_sssp_icos_no_eval['BuildingID'].nunique() # There are 185 buildings without an evaluation.
# Some buildings have more than one 'building area' row, yielding 208 rows for these 185 buildings.
# Out:
# 185

# %%
mask = merged_sssp_icos_no_eval['buildings match'] == 'Yes'
merged_sssp_icos_no_eval_match = merged_sssp_icos_no_eval[mask]
merged_sssp_icos_no_eval_match['BuildingID'].nunique() 
# There are 160 buildings with matching names and matching building IDs between the SSSP and ICOS
# that have no evaluations in ICOS.
# Out:
# 160

# %%
# Confirming that these buildings have no evaluations
merged_sssp_icos_no_eval_match['Building_HasEvaluation'].value_counts()
# Out:
# Building_HasEvaluation
# No    160
# Name: count, dtype: int64

# %%
merged_sssp_icos_no_eval_match[['District', 'Site_SSSP', 'Site_ICOS', 'original_Building_SSSP', \
                         'Building_ICOS', 'BuildingID', 'original_BuildingID_SSSP', 'Building_HasEvaluation']]
# Out:
#                  District  \
# 7       Burlington-Edison
# 8       Burlington-Edison
# 9       Burlington-Edison
# 11      Burlington-Edison
# 17              Centralia
# 18            Clover Park
# 21               Ferndale
# 24                Hoquiam
# 25                Hoquiam
# 31                  Kelso
# 37             Marysville
# 38             Marysville
# 39             Marysville
# 42            Mount Baker
# 48                 Pe Ell
# 49              Peninsula
# 64              Snohomish
# 66              Snohomish
# 78                 Tacoma
# 79                 Tacoma
# 84               Woodland
# 87               Woodland
# 88      Bainbridge Island
# 89      Bainbridge Island
# 94      Bainbridge Island
# 97             Bellingham
# 99                Brinnon
# 100     Burlington-Edison
# 101     Burlington-Edison
# 113               Cascade
# 117             Centralia
# 119             Centralia
# 120              Chimacum
# 121           Clover Park
# 122           Clover Park
# 123           Clover Park
# 137               Ephrata
# 138               Ephrata
# 139               Ephrata
# 152              Ferndale
# 180             Hockinson
# 181               Hoquiam
# 183               Hoquiam
# 184               Hoquiam
# 188                 Kelso
# 189             La Center
# 190       Lake Washington
# 200          Lopez Island
# 203         Mary M Knight
# 204            Marysville
# 205            Marysville
# 206            Marysville
# 207            Marysville
# 211            Marysville
# 213            Marysville
# 214            Marysville
# 215            Marysville
# 235              Napavine
# 236              Napavine
# 237              Napavine
# 240           North Beach
# 243           North Mason
# 244           North Mason
# 245           North River
# 247           North River
# 248           North River
# 249            Northshore
# 250            Northshore
# 251            Northshore
# 252            Northshore
# 253            Northshore
# 254            Northshore
# 255            Northshore
# 256            Northshore
# 265                Orting
# 270             Peninsula
# 271             Peninsula
# 272             Peninsula
# 273             Peninsula
# 274             Peninsula
# 275             Peninsula
# 276             Peninsula
# 296            Ridgefield
# 301              Skamania
# 302             Snohomish
# 303             Snohomish
# 304             Snohomish
# 305             Snohomish
# 306             Snohomish
# 307             Snohomish
# 308             Snohomish
# 309            South Bend
# 327       Stanwood-Camano
# 328       Stanwood-Camano
# 329      Stevenson-Carson
# 330      Stevenson-Carson
# 331      Stevenson-Carson
# 332      Stevenson-Carson
# 334                Tacoma
# 335                Tacoma
# 336                Tacoma
# 337                Tacoma
# 338                Tacoma
# 345      University Place
# 346      University Place
# 348             Wahkiakum
# 356        Willapa Valley
# 358              Woodland
# 374                 Camas
# 389               Ephrata
# 405         Granite Falls
# 406         Granite Falls
# 409             Hockinson
# 410             Hockinson
# 411             Hockinson
# 412             Hockinson
# 413             Hockinson
# 414             Hockinson
# 417       Lake Washington
# 419          Lopez Island
# 420          Lopez Island
# 428           Ocean Beach
# 432                Pe Ell
# 433             Peninsula
# 436             Snohomish
# 437                Tacoma
# 438                Tacoma
# 439                Tacoma
# 440                Tacoma
# 441                Tacoma
# 444  West Valley (Yakima)
# 445  West Valley (Yakima)
# 454     Bainbridge Island
# 457     Bainbridge Island
# 464            Bellingham
# 470               Cascade
# 478              Chimacum
# 479           Clover Park
# 484             Dieringer
# 498       Lake Washington
# 499       Lake Washington
# 500       Lake Washington
# 503         Mary M Knight
# 504            Marysville
# 505            Marysville
# 506            Marysville
# 520               Olympia
# 521               Olympia
# 522               Olympia
# 525             Peninsula
# 526             Peninsula
# 527             Peninsula
# 528         Port Townsend
# 536                Tacoma
# 537                Tacoma
# 538                Tacoma
# 539                Tacoma
# 540                Tacoma
# 541                Tacoma
# 551           White River
#
#                                                    Site_SSSP  \
# 7                              Burlington-Edison High School
# 8                              Burlington-Edison High School
# 9                              Burlington-Edison High School
# 11                              West View Elementary School)
# 17                              Washington Elementary School
# 18                                Tillicum Elementary School
# 21                                         Custer Elementary
# 24                                 Central Elementary School
# 25                                 Emerson Elementary School
# 31                             Rose Valley Elementary School
# 37                        Marysville Pilchuck Sr High School
# 38                        Marysville Pilchuck Sr High School
# 39                        Marysville Pilchuck Sr High School
# 42                                    Acme Elementary School
# 48                                             Pe Ell School
# 49                                     Peninsula High School
# 64                                Cathcart Elementary School
# 66                                 Central Elementary School
# 78                         Tacoma School of the Arts-Pacific
# 79                                    Willie Stewart Academy
# 84                           Woodland Middle School (old HS)
# 87                           Woodland Middle School (old HS)
# 88                                    Bainbridge High School
# 89                                  Commodore Options School
# 94                                  Ordway Elementary School
# 97                               Roosevelt Elementary School
# 99                                 Brinnon Elementary School
# 100                            Burlington-Edison High School
# 101                            Burlington-Edison High School
# 113                                     Beaver Valley School
# 117                                  Centralia Middle School
# 119                                Oakview Elementary School
# 120                                   Chimacum Middle School
# 121                                 Custer Elementary School
# 122                               Oakbrook Elementary School
# 123                               Oakbrook Elementary School
# 137                                      Ephrata High School
# 138                                      Ephrata High School
# 139                                  Grant Elementary School
# 152                                Central Elementary School
# 180               Hockinson Heights Elementary School (East)
# 181                                      Hoquiam High School
# 183                                      Hoquiam High School
# 184                                      Hoquiam High School
# 188                                   Coweeman Middle School
# 189                    La Center Elementary & Middle Schools
# 190                               Rockwell Elementary School
# 200                                 Lopez Middle High School
# 203                                    Mary M. Knight School
# 204                                Cascade Elementary School
# 205                                Cascade Elementary School
# 206                                Cascade Elementary School
# 207                                Cascade Elementary School
# 211                       Marysville Pilchuck Sr High School
# 213                       Marysville Pilchuck Sr High School
# 214                       Marysville Pilchuck Sr High School
# 215                       Marysville Pilchuck Sr High School
# 235                               Napavine Elementary School
# 236                       Napavine Junior Senior High School
# 237                       Napavine Junior Senior High School
# 240                    North Beach Junior/Senior High School
# 243                                Belfair Elementary School
# 244                                Belfair Elementary School
# 245                                       North River School
# 247                                       North River School
# 248                                       North River School
# 249                           Canyon Creek Elementary School
# 250                           Canyon Creek Elementary School
# 251                        Crystal Springs Elementary School
# 252                        Crystal Springs Elementary School
# 253                        Crystal Springs Elementary School
# 254                        Crystal Springs Elementary School
# 255                           Shelton View Elementary School
# 256                           Shelton View Elementary School
# 265                                    Orting Primary School
# 270                              Discovery Elementary School
# 271                                   Gig Harbor High School
# 272                                   Gig Harbor High School
# 273                                    Peninsula High School
# 274                                    Peninsula High School
# 275                                    Peninsula High School
# 276                                    Peninsula High School
# 296                            South Ridge Elementary School
# 301                               Skamania Elementary School
# 302                               Cathcart Elementary School
# 303                               Cathcart Elementary School
# 304                               Cathcart Elementary School
# 305                               Cathcart Elementary School
# 306                               Cathcart Elementary School
# 307                               Cathcart Elementary School
# 308                                Emerson Elementary School
# 309                             South Bend Jr/Sr High School
# 327                                   Stanwood Middle School
# 328                              Twin City Elementary School
# 329                                 Carson Elementary School
# 330                                    Stevenson High School
# 331                                    Stevenson High School
# 332                              Wind River Education Center
# 334                                 DeLong Elementary School
# 335                                   Mann Elementary School
# 336                         Point Defiance Elementary School
# 337                                   Reed Elementary School
# 338                                Stanley Elementary School
# 345                                Curtis Senior High School
# 346                                    Sunset Primary School
# 348  Julius A. Wendt Elementary/John C. Thomas Middle School
# 356                                Willapa Elementary School
# 358                               Columbia Elementary School
# 374                            Dorothy Fox Elementary School
# 389                                           Parkway School
# 405                   Granite Falls Middle School (form. HS)
# 406                           Mountain Way Elementary School
# 409               Hockinson Heights Elementary School (East)
# 410               Hockinson Heights Elementary School (East)
# 411               Hockinson Heights Elementary School (East)
# 412               Hockinson Heights Elementary School (East)
# 413               Hockinson Heights Elementary School (East)
# 414               Hockinson Heights Elementary School (East)
# 417                               Einstein Elementary School
# 419                                  Lopez Elementary School
# 420                                 Lopez Middle High School
# 428                                                Kaino Gym
# 432                                            Pe Ell School
# 433                                    Peninsula High School
# 436                                Emerson Elementary School
# 437                                 DeLong Elementary School
# 438                               Franklin Elementary School
# 439                              Larchmont Elementary School
# 440                                 Lister Elementary School
# 441                              Roosevelt Elementary School
# 444                           West Valley Junior High School
# 445                           West Valley Junior High School
# 454                                   Bainbridge High School
# 457                                   Woodward Middle School
# 464                                    Whatcom Middle School
# 470                                     Beaver Valley School
# 478                                   Chimacum Middle School
# 479                                 Custer Elementary School
# 484                                North Tapps Middle School
# 498                              Dickinson Elementary School
# 499                                           Emerson Campus
# 500                                 Wilder Elementary School
# 503                                    Mary M. Knight School
# 504                   Marysville Pilchuck Senior High School
# 505                   Marysville Pilchuck Senior High School
# 506                      Quil Ceda Tulalip Elementary School
# 520                          Boston Harbor Elementary School
# 521                          Thurgood Marshall Middle School
# 522                          Thurgood Marshall Middle School
# 525                                   Gig Harbor High School
# 526                           Minter Creek Elementary School
# 527                                Voyager Elementary School
# 528                                 Blue Heron Middle School
# 536                                 Edison Elementary School
# 537                           Manitou Park Elementary School
# 538                       Northeast Tacoma Elementary School
# 539                       Northeast Tacoma Elementary School
# 540                               Sheridan Elementary School
# 541                                Stanley Elementary School
# 551                        Mountain Meadow Elementary School
#
#                                                    Site_ICOS  \
# 7                              Burlington-Edison High School
# 8                              Burlington-Edison High School
# 9                              Burlington-Edison High School
# 11                               West View Elementary School
# 17                              Washington Elementary School
# 18                                Tillicum Elementary School
# 21                                         Custer Elementary
# 24                                 Central Elementary School
# 25                                 Emerson Elementary School
# 31                             Rose Valley Elementary School
# 37                    Marysville Pilchuck Senior High School
# 38                    Marysville Pilchuck Senior High School
# 39                    Marysville Pilchuck Senior High School
# 42                                    Acme Elementary School
# 48                                             Pe Ell School
# 49                                     Peninsula High School
# 64                                Cathcart Elementary School
# 66                                 Central Elementary School
# 78                         Tacoma School of the Arts-Pacific
# 79                                    Willie Stewart Academy
# 84                           Woodland Middle School (old HS)
# 87                           Woodland Middle School (old HS)
# 88                                    Bainbridge High School
# 89                                  Commodore Options School
# 94                                  Ordway Elementary School
# 97                               Roosevelt Elementary School
# 99                                 Brinnon Elementary School
# 100                            Burlington-Edison High School
# 101                            Burlington-Edison High School
# 113                                     Beaver Valley School
# 117                                  Centralia Middle School
# 119                                Oakview Elementary School
# 120                                   Chimacum Middle School
# 121                                 Custer Elementary School
# 122                               Oakbrook Elementary School
# 123                               Oakbrook Elementary School
# 137                                      Ephrata High School
# 138                                      Ephrata High School
# 139                                  Grant Elementary School
# 152                                Central Elementary School
# 180               Hockinson Heights Elementary School (East)
# 181                                      Hoquiam High School
# 183                                      Hoquiam High School
# 184                                      Hoquiam High School
# 188                                   Coweeman Middle School
# 189                    La Center Elementary & Middle Schools
# 190                               Rockwell Elementary School
# 200                                 Lopez Middle High School
# 203                                    Mary M. Knight School
# 204                                Cascade Elementary School
# 205                                Cascade Elementary School
# 206                                Cascade Elementary School
# 207                                Cascade Elementary School
# 211                   Marysville Pilchuck Senior High School
# 213                   Marysville Pilchuck Senior High School
# 214                   Marysville Pilchuck Senior High School
# 215                   Marysville Pilchuck Senior High School
# 235                               Napavine Elementary School
# 236                       Napavine Junior Senior High School
# 237                       Napavine Junior Senior High School
# 240                    North Beach Junior/Senior High School
# 243                                Belfair Elementary School
# 244                                Belfair Elementary School
# 245                                       North River School
# 247                                       North River School
# 248                                       North River School
# 249                           Canyon Creek Elementary School
# 250                           Canyon Creek Elementary School
# 251                        Crystal Springs Elementary School
# 252                        Crystal Springs Elementary School
# 253                        Crystal Springs Elementary School
# 254                        Crystal Springs Elementary School
# 255                           Shelton View Elementary School
# 256                           Shelton View Elementary School
# 265                                    Orting Primary School
# 270                              Discovery Elementary School
# 271                                   Gig Harbor High School
# 272                                   Gig Harbor High School
# 273                                    Peninsula High School
# 274                                    Peninsula High School
# 275                                    Peninsula High School
# 276                                    Peninsula High School
# 296                            South Ridge Elementary School
# 301                               Skamania Elementary School
# 302                               Cathcart Elementary School
# 303                               Cathcart Elementary School
# 304                               Cathcart Elementary School
# 305                               Cathcart Elementary School
# 306                               Cathcart Elementary School
# 307                               Cathcart Elementary School
# 308                                Emerson Elementary School
# 309                             South Bend Jr/Sr High School
# 327                                   Stanwood Middle School
# 328                              Twin City Elementary School
# 329                                 Carson Elementary School
# 330                                    Stevenson High School
# 331                                    Stevenson High School
# 332                              Wind River Education Center
# 334                                 DeLong Elementary School
# 335                                   Mann Elementary School
# 336                         Point Defiance Elementary School
# 337                                   Reed Elementary School
# 338                                Stanley Elementary School
# 345                                Curtis Senior High School
# 346                                    Sunset Primary School
# 348  Julius A. Wendt Elementary/John C. Thomas Middle School
# 356                                Willapa Elementary School
# 358                               Columbia Elementary School
# 374                            Dorothy Fox Elementary School
# 389                                           Parkway School
# 405                   Granite Falls Middle School (form. HS)
# 406                           Mountain Way Elementary School
# 409               Hockinson Heights Elementary School (East)
# 410               Hockinson Heights Elementary School (East)
# 411               Hockinson Heights Elementary School (East)
# 412               Hockinson Heights Elementary School (East)
# 413               Hockinson Heights Elementary School (East)
# 414               Hockinson Heights Elementary School (East)
# 417                               Einstein Elementary School
# 419                                  Lopez Elementary School
# 420                                 Lopez Middle High School
# 428                                                Kaino Gym
# 432                                            Pe Ell School
# 433                                    Peninsula High School
# 436                                Emerson Elementary School
# 437                                 DeLong Elementary School
# 438                               Franklin Elementary School
# 439                              Larchmont Elementary School
# 440                                 Lister Elementary School
# 441                              Roosevelt Elementary School
# 444                           West Valley Junior High School
# 445                           West Valley Junior High School
# 454                                   Bainbridge High School
# 457                                   Woodward Middle School
# 464                                    Whatcom Middle School
# 470                                     Beaver Valley School
# 478                                   Chimacum Middle School
# 479                                 Custer Elementary School
# 484                                North Tapps Middle School
# 498                              Dickinson Elementary School
# 499                                           Emerson Campus
# 500                                 Wilder Elementary School
# 503                                    Mary M. Knight School
# 504                   Marysville Pilchuck Senior High School
# 505                   Marysville Pilchuck Senior High School
# 506                      Quil Ceda Tulalip Elementary School
# 520                          Boston Harbor Elementary School
# 521                          Thurgood Marshall Middle School
# 522                          Thurgood Marshall Middle School
# 525                                   Gig Harbor High School
# 526                           Minter Creek Elementary School
# 527                                Voyager Elementary School
# 528                                 Blue Heron Middle School
# 536                                 Edison Elementary School
# 537                           Manitou Park Elementary School
# 538                       Northeast Tacoma Elementary School
# 539                       Northeast Tacoma Elementary School
# 540                               Sheridan Elementary School
# 541                                Stanley Elementary School
# 551                        Mountain Meadow Elementary School
#
#                      original_Building_SSSP  \
# 7                    Art/Tiger TUB Building
# 8                    Cafeteria and 400 Wing
# 9                                       CTE
# 11                            Main Building
# 17                            Main Building
# 18                 Classroom Building - TL1
# 21                            Main Building
# 24                            Main Building
# 25                            Main Building
# 31                            Main Building
# 37                      Auditorium - Bldg K
# 38                         Library - Bldg J
# 39                   Pool Building - Bldg L
# 42                            Main Building
# 48                            Main Building
# 49                       Main Building (100
# 64                             100 Building
# 66                            Main Building
# 78                         SOTA Pacific Ave
# 79                                Main Bldg
# 84                            Main Building
# 87        Shared High School /Middle School
# 88                             500 Building
# 89                 Commodore Options School
# 94                            Main Building
# 97                            Main Building
# 99                            Main Building
# 100                                500 Wing
# 101                Admin/Classroom Building
# 113                 Old Winton School House
# 117                           Main Building
# 119                           Main Building
# 120                Middle School Bldg 100 B
# 121               Second Classroom Building
# 122                First Classroom Building
# 123                               Gym / MPR
# 137  1937 Annex (Former Beezley Springs ES)
# 138              Performing Arts Center PAC
# 139                           Main Building
# 152                           Main Building
# 180                          Building 800 H
# 181                    D-Business Education
# 183                            F-Humanities
# 184                        G-Little Theater
# 188                           Main Building
# 189         Building 300 - ES Main Building
# 190                           Main Building
# 200             Junior Senior High Building
# 203                       Elementary School
# 204                                  Unit A
# 205                                  Unit B
# 206                                  Unit C
# 207                                  Unit D
# 211       Arts and Crafts Building - Bldg B
# 213                  East Building - Bldg H
# 214         Gym & New Food Commons - Bldg M
# 215          Life Science Building - Bldg F
# 235                           Main Building
# 236                                   Annex
# 237                                    Main
# 240                           Main Building
# 243                      Gymnasium Building
# 244                           Main Building
# 245                              Elementary
# 247            High School & Admin Building
# 248             Talley Building (Music/Art)
# 249          Building A - Classroom/Library
# 250              Building C - Cafeteria/Gym
# 251                      Building 1 - Admin
# 252         Building 2 - Classrooms/Kitchen
# 253               Building 3/4 - Classrooms
# 254                 Building 5 - Classrooms
# 255              Building A1/10 - Classroom
# 256                        Building C - Gym
# 265                           Main Building
# 270                           Main Building
# 271                           Main Building
# 272                         Voc-Ed Building
# 273                            500 Building
# 274                            600 Building
# 275          800 Building - Auditorium Area
# 276            900 Building - Pool Building
# 296                           Main Building
# 301                           Main Building
# 302                            200 Building
# 303                            300 Building
# 304                            400 Building
# 305                            500 Building
# 306                            600 Building
# 307                            700 Building
# 308                           Main Building
# 309               Main Building High School
# 327                      Building 3 - Music
# 328                           Main Building
# 329                           Main Building
# 330                           Main Building
# 331                     Vocational Building
# 332                           Main Building
# 334                    Original Bldg-Bldg A
# 335                           Main Building
# 336                           Main Building
# 337                           Main Building
# 338                                Gym Bldg
# 345                            500 Building
# 346                           Main Building
# 348             J A Wendt Elementary School
# 356                           Main Building
# 358                           Main Building
# 374                           Main Building
# 389                           Main Building
# 405                  Multi-Purpose Building
# 406                           Main Building
# 409                          Building 100 A
# 410                          Building 200 C
# 411                          Building 300 D
# 412                          Building 400 B
# 413                          Building 500 E
# 414                          Building 600 F
# 417                           Main Building
# 419                              Elementary
# 420                       Gym/Tech Building
# 428                               Kaino Gym
# 432                          Fitness Center
# 433                   700 Building - Voc Ag
# 436                                   Annex
# 437                       First Bldg-Bldg B
# 438                           Main Building
# 439                       Original Building
# 440                           Main Building
# 441                               Main Bldg
# 444                     WVJH (Gym Building)
# 445                    WVJH (Main Building)
# 454                            300 Building
# 457                           Main Building
# 464                          Music Building
# 470                           Main Building
# 478                  Middle School Bldg 200
# 479                                 Library
# 484                           Main Building
# 498                           Main Building
# 499                                 Emerson
# 500                           Main Building
# 503                    High School Building
# 504      Physical Science Building - Bldg S
# 505                 South Building - Bldg N
# 506                           Main Building
# 520                           Main Building
# 521                            Gym Building
# 522                           Main Building
# 525                      Two-Story Building
# 526                           Main Building
# 527                           Main Building
# 528                           Main Building
# 536                           Main Building
# 537                           Main Building
# 538                         Gym Bldg-Bldg 2
# 539                        Main Bldg-Bldg 1
# 540                           Main Building
# 541                              First Bldg
# 551                           Main Building
#
#                               Building_ICOS  BuildingID  \
# 7                    Art/Tiger TUB Building       50119
# 8                    Cafeteria and 400 Wing       50117
# 9                                       CTE       50110
# 11                            Main Building       50095
# 17                            Main Building       57962
# 18                 Classroom Building - TL1       50186
# 21                            Main Building       54976
# 24                            Main Building       58356
# 25                            Main Building       58357
# 31                            Main Building       58396
# 37                      Auditorium - Bldg K       56248
# 38                         Library - Bldg J       56244
# 39                   Pool Building - Bldg L       56233
# 42                Main Building - AA Bldg A       56410
# 48                            Main Building       51321
# 49       Main Building (100, 200, 300, 400)       58796
# 64                100 Building - S&S Area 4       57090
# 66                            Main Building       57085
# 78                         SOTA Pacific Ave       59768
# 79                                Main Bldg       59727
# 84                            Main Building       60193
# 87        Shared High School /Middle School       60192
# 88                             500 Building       57410
# 89                 Commodore Options School       57422
# 94                            Main Building       57416
# 97                            Main Building       54493
# 99                            Main Building       57777
# 100                                500 Wing       50112
# 101                Admin/Classroom Building       50118
# 113                 Old Winton School House       51677
# 117                           Main Building       57953
# 119                           Main Building       57970
# 120                Middle School Bldg 100 B       58032
# 121         Second Classroom Building - CU1       50240
# 122          First Classroom Building - OB1       50244
# 123                         Gym / MPR - OB2       50245
# 137  1937 Annex (Former Beezley Springs ES)       51934
# 138              Performing Arts Center PAC       51932
# 139                           Main Building       51927
# 152                           Main Building       54971
# 180                          Building 800 H       58325
# 181                    D-Business Education       58347
# 183                            F-Humanities       58345
# 184                        G-Little Theater       58346
# 188                           Main Building       58393
# 189         Building 300 - ES Main Building       50901
# 190                           Main Building       55771
# 200             Junior Senior High Building       56068
# 203                       Elementary School       50921
# 204                                  Unit A       56103
# 205                                  Unit B       56101
# 206                                  Unit C       56104
# 207                                  Unit D       56102
# 211       Arts and Crafts Building - Bldg B       56254
# 213                  East Building - Bldg H       56240
# 214         Gym & New Food Commons - Bldg M       56246
# 215          Life Science Building - Bldg F       56253
# 235                           Main Building       58512
# 236                                   Annex       58513
# 237                                    Main       58514
# 240                           Main Building       58529
# 243                      Gymnasium Building       58613
# 244                           Main Building       58614
# 245                              Elementary       58630
# 247            High School & Admin Building       58631
# 248             Talley Building (Music/Art)       58636
# 249          Building A - Classroom/Library       56750
# 250              Building C - Cafeteria/Gym       56753
# 251                      Building 1 - Admin       56775
# 252         Building 2 - Classrooms/Kitchen       56774
# 253               Building 3/4 - Classrooms       56772
# 254                 Building 5 - Classrooms       56770
# 255              Building A1/10 - Classroom       56732
# 256                        Building C - Gym       56727
# 265                           Main Building       58761
# 270                           Main Building       58839
# 271                           Main Building       58821
# 272                         Voc-Ed Building       58820
# 273                            500 Building       58793
# 274                            600 Building       58795
# 275          800 Building - Auditorium Area       58792
# 276            900 Building - Pool Building       58794
# 296                           Main Building       59234
# 301                           Main Building       59377
# 302               200 Building - S&S Area 5       57091
# 303               300 Building - S&S Area 6       57089
# 304          400 Building - S&S Areas 7 & 8       57088
# 305                   500 Building - Area 3       57092
# 306               600 Building - S&S Area 2       57094
# 307               700 Building - S&S Area 1       57093
# 308                           Main Building       57132
# 309               Main Building High School       51397
# 327     Building 3 - Music (Band and Choir)       51449
# 328                           Main Building       51411
# 329                           Main Building       59495
# 330                           Main Building       59488
# 331                     Vocational Building       59491
# 332                           Main Building       59499
# 334                    Original Bldg-Bldg A       59597
# 335                           Main Building       59664
# 336                           Main Building       59730
# 337                           Main Building       59628
# 338                                Gym Bldg       59635
# 345                            500 Building       59969
# 346                           Main Building       59982
# 348             J A Wendt Elementary School       53717
# 356                           Main Building       60150
# 358                           Main Building       60181
# 374                           Main Building       57808
# 389                           Main Building       51938
# 405                  Multi-Purpose Building       55030
# 406                           Main Building       55012
# 409                          Building 100 A       58331
# 410                          Building 200 C       58332
# 411                          Building 300 D       58328
# 412                          Building 400 B       58326
# 413                          Building 500 E       58327
# 414                          Building 600 F       58329
# 417                           Main Building       55836
# 419                              Elementary       56065
# 420                       Gym/Tech Building       56067
# 428                               Kaino Gym       58644
# 432                          Fitness Center       51320
# 433                   700 Building - Voc Ag       58791
# 436                                   Annex       57133
# 437                       First Bldg-Bldg B       59598
# 438                           Main Building       59589
# 439                       Original Building       59804
# 440                           Main Building       59790
# 441                               Main Bldg       59688
# 444                     WVJH (Gym Building)       51547
# 445                    WVJH (Main Building)       51546
# 454                            300 Building       57407
# 457                           Main Building       57424
# 464                          Music Building       54468
# 470                           Main Building       51675
# 478                  Middle School Bldg 200       58031
# 479                           Library - CU2       50243
# 484                           Main Building       58058
# 498                           Main Building       55935
# 499                                 Emerson       55920
# 500                           Main Building       55846
# 503                    High School Building       50924
# 504      Physical Science Building - Bldg S       56251
# 505                 South Building - Bldg N       56247
# 506                           Main Building       56204
# 520                           Main Building       58698
# 521                            Gym Building       58671
# 522                           Main Building       58672
# 525                      Two-Story Building       58819
# 526                           Main Building       58834
# 527                           Main Building       58817
# 528                           Main Building       58917
# 536                           Main Building       59747
# 537                           Main Building       59601
# 538                         Gym Bldg-Bldg 2       59627
# 539                        Main Bldg-Bldg 1       59626
# 540                           Main Building       59723
# 541                              First Bldg       59636
# 551                           Main Building       51616
#
#      original_BuildingID_SSSP Building_HasEvaluation
# 7                       50119                     No
# 8                       50117                     No
# 9                       50110                     No
# 11                      50095                     No
# 17                      57962                     No
# 18                      50186                     No
# 21                      54976                     No
# 24                      58356                     No
# 25                      58357                     No
# 31                      58396                     No
# 37                      56248                     No
# 38                      56244                     No
# 39                      56233                     No
# 42                      56410                     No
# 48                      51321                     No
# 49                      58796                     No
# 64                      57090                     No
# 66                      57085                     No
# 78                      59768                     No
# 79                      59727                     No
# 84                      60193                     No
# 87                      60192                     No
# 88                      57410                     No
# 89                      57422                     No
# 94                      57416                     No
# 97                      54493                     No
# 99                      57777                     No
# 100                     50112                     No
# 101                     50118                     No
# 113                     51677                     No
# 117                     57953                     No
# 119                     57970                     No
# 120                     58032                     No
# 121                     50240                     No
# 122                     50244                     No
# 123                     50245                     No
# 137                     51934                     No
# 138                     51932                     No
# 139                     51927                     No
# 152                     54971                     No
# 180                     58325                     No
# 181                     58347                     No
# 183                     58345                     No
# 184                     58346                     No
# 188                     58393                     No
# 189                     50901                     No
# 190                     55771                     No
# 200                     56068                     No
# 203                     50921                     No
# 204                     56103                     No
# 205                     56101                     No
# 206                     56104                     No
# 207                     56102                     No
# 211                     56254                     No
# 213                     56240                     No
# 214                     56246                     No
# 215                     56253                     No
# 235                     58512                     No
# 236                     58513                     No
# 237                     58514                     No
# 240                     58529                     No
# 243                     58613                     No
# 244                     58614                     No
# 245                     58630                     No
# 247                     58631                     No
# 248                     58636                     No
# 249                     56750                     No
# 250                     56753                     No
# 251                     56775                     No
# 252                     56774                     No
# 253                     56772                     No
# 254                     56770                     No
# 255                     56732                     No
# 256                     56727                     No
# 265                     58761                     No
# 270                     58839                     No
# 271                     58821                     No
# 272                     58820                     No
# 273                     58793                     No
# 274                     58795                     No
# 275                     58792                     No
# 276                     58794                     No
# 296                     59234                     No
# 301                     59377                     No
# 302                     57091                     No
# 303                     57089                     No
# 304                     57088                     No
# 305                     57092                     No
# 306                     57094                     No
# 307                     57093                     No
# 308                     57132                     No
# 309                     51397                     No
# 327                     51449                     No
# 328                     51411                     No
# 329                     59495                     No
# 330                     59488                     No
# 331                     59491                     No
# 332                     59499                     No
# 334                     59597                     No
# 335                     59664                     No
# 336                     59730                     No
# 337                     59628                     No
# 338                     59635                     No
# 345                     59969                     No
# 346                     59982                     No
# 348                     53717                     No
# 356                     60150                     No
# 358                     60181                     No
# 374                     57808                     No
# 389                     51938                     No
# 405                     55030                     No
# 406                     55012                     No
# 409                     58331                     No
# 410                     58332                     No
# 411                     58328                     No
# 412                     58326                     No
# 413                     58327                     No
# 414                     58329                     No
# 417                     55836                     No
# 419                     56065                     No
# 420                     56067                     No
# 428                     58644                     No
# 432                     51320                     No
# 433                     58791                     No
# 436                     57133                     No
# 437                     59598                     No
# 438                     59589                     No
# 439                     59804                     No
# 440                     59790                     No
# 441                     59688                     No
# 444                     51547                     No
# 445                     51546                     No
# 454                     57407                     No
# 457                     57424                     No
# 464                     54468                     No
# 470                     51675                     No
# 478                     58031                     No
# 479                     50243                     No
# 484                     58058                     No
# 498                     55935                     No
# 499                     55920                     No
# 500                     55846                     No
# 503                     50924                     No
# 504                     56251                     No
# 505                     56247                     No
# 506                     56204                     No
# 520                     58698                     No
# 521                     58671                     No
# 522                     58672                     No
# 525                     58819                     No
# 526                     58834                     No
# 527                     58817                     No
# 528                     58917                     No
# 536                     59747                     No
# 537                     59601                     No
# 538                     59627                     No
# 539                     59626                     No
# 540                     59723                     No
# 541                     59636                     No
# 551                     51616                     No
