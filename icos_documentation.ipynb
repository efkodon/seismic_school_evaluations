# %%
import pandas as pd
import seaborn as sns
import numpy as np
from numpy import nan

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('max_seq_item', None)

# %%
# DOCUMENTATION FOR INFORMATION AND CONDITION OF SCHOOLS (ICOS), Pre-Disaster Mitigation module.
# Documentation was received from WA Office of Superintendent of Public Instruction (OSPI), 8/14/24, via public 
# records request to accompany the ICOS dataset used throughout this project.
# https://www.k12.wa.us/policy-funding/school-buildings-facilities/information-and-condition-schools-icos

# %%
icos_glossary=pd.read_csv("icos_documentation/icos_glossary.csv")

# %%
icos_glossary['Notes'] = icos_glossary['Notes'].fillna("n/a")

# %%
icos_glossary
# Out:
#                                  Column  \
# 0                              District
# 1                                  Site
# 2                         Site_Latitude
# 3                        Site_Longitude
# 4                             Site_Type
# 5                    Site_EQHazardLevel
# 6                      Site_EQRiskLevel
# 7                             Site_Soil
# 8                     Site_Liquefaction
# 9           Site_GroundMotionPercentile
# 10            Site_HasGeotechnicalStudy
# 11               Site_ShearWaveVelocity
# 12                             Building
# 13                        Building_Type
# 14               Building_HasEvaluation
# 15                   Building_YearBuilt
# 16                   Building_GrossSqFt
# 17                    BuildingArea_Name
# 18               BuildingArea_YearBuilt
# 19                BuildingArea_CodeYear
# 20          BuildingArea_NumberOfFloors
# 21        BuildingArea_ConstructionType
# ...

# %%
icos_hazard_levels=pd.read_csv("icos_documentation/icos_hazard_levels.csv")

# %%
# Adjusting the formatting to match the original document
icos_hazard_levels['Name'] = icos_hazard_levels['Name'].fillna("None")
icos_hazard_levels['Earthquake Hazard'] = icos_hazard_levels['Earthquake Hazard'].fillna(" ")

# %%
icos_hazard_levels
# Out:
#         Name  \
# 0  Very High
# 1       High
# 2   Moderate
# 3        Low
# 4       None
#
#                                                                                                                               Earthquake Hazard
# 0                                           Site has a 2% in 50 year PGA value greater than 59.5 and Liquefaction greater than Low to Moderate.
# 1  Site has a 2% in 50 year PGA value greater than 59.9 or a 2% in 50 year PGA greater than 29.5 and Liquefaction greater than Low to Moderate.
# 2  Site has a 2% in 50 year PGA value greater than 29.5 or a 2% in 50 year PGA greater than 19.5 and Liquefaction greater than Low to Moderate.
# 3                                                      Site has a 2% in 50 year PGA value less than 19.5 and a Liquefaction less than moderate.
# 4

# %%
icos_risk_levels=pd.read_csv("icos_documentation/icos_risk_levels.csv")

# %%
# Adjusting the formatting to match the original document
icos_risk_levels['Name'] = icos_risk_levels['Name'].fillna("None")
icos_risk_levels['Earthquake'] = icos_risk_levels['Earthquake'].fillna(" ")

# %%
icos_risk_levels
# Out:
#         Name  \
# 0  Very High
# 1       High
# 2   Moderate
# 3        Low
# 4       None
#
#                                                                                   Earthquake
# 0  Sites greatest risk building has EPAT life safety risk of High to Very High or Very High.
# 1           Sites greatest risk building has EPAT life safety risk of Moderate-High or High.
# 2        Sites greatest risk building has EPAT life safety risk of Low-Moderate or Moderate.
# 3                 Sites greatest risk building has EPAT life safety risk of Very Low or Low.
# 4

# %%
icos_evaluation_types=pd.read_csv("icos_documentation/icos_evaluation_types.csv")

# %%
icos_evaluation_types
# Out:
#                                                        Name
# 0                                    Rapid Visual Screening
# 1            ASCE 41-13 Structural Tier 1 (Screening Phase)
# 2           ASCE 41-13 Structural Tier 2 (Evaluation Phase)
# 3  ASCE 41-13 Structural Tier 3 (Detailed Evaluation Phase)
# 4                                 ASCE 41-13 Non-Structural
# 5                                     ASCE 31-03 Structural
# 6                                 ASCE 31-03 Non-Structural
# 7                                            BCE Evaluation
# 8                         Equivalent Lateral Force Analysis

# %%
icos_construction_types=pd.read_csv("icos_documentation/icos_construction_types.csv")

# %%
icos_construction_types
# Out:
#                                                                    Name  Code  \
# 0                                                     Wood, Light Frame    W1
# 1                  Wood, Commercial and Industrial (>5,000 square feet)    W2
# 2                                                    Steel Moment Frame    S1
# 3                                                    Steel Braced Frame    S2
# 4                                                     Steel Light Frame    S3
# 5                   Steel Frame with Cast-in-Place Concrete Shear Walls    S4
# 6                    Steel Frame with Unreinforced Masonry Infill Walls    S5
# 7                           Reinforced Concrete Moment Resisting Frames    C1
# 8                                                  Concrete Shear Walls    C2
# 9                        Concrete Frame Buildings with URM Infill Walls    C3
# 10                                       Precast Concrete Tilt-Up Walls   PC1
# ...
